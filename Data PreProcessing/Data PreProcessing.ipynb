# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("Students_marks.csv")

# %%
data.head()
# Out:
#    Roll No.     Name  Data Structure  Mathematics  Operating System
# 0         1  Avneet               25           19                17
# 1         2      Jay              23           21                14
# 2         3   Sadaf               28           23                21
# 3         4  Prakash              21           27                25
# 4         5   Sarita              23           22                 9

# %%
data.describe()
# Out:
#        Roll No.  Data Structure  Mathematics  Operating System
# count  10.00000       10.000000     10.00000          10.00000
# mean    5.50000       40.700000     23.10000          19.90000
# std     3.02765       52.493492      3.60401           5.95259
# min     1.00000       21.000000     18.00000           9.00000
# 25%     3.25000       23.000000     21.25000          15.50000
# 50%     5.50000       24.000000     22.50000          21.50000
# 75%     7.75000       25.750000     24.75000          24.50000
# max    10.00000      190.000000     30.00000          28.00000

# %%
data
# Out:
#    Roll No.     Name  Data Structure  Mathematics  Operating System
# 0         1  Avneet               25           19                17
# 1         2      Jay              23           21                14
# 2         3   Sadaf               28           23                21
# 3         4  Prakash              21           27                25
# 4         5   Sarita              23           22                 9
# 5         6  Vasudha             190           30                28
# 6         7    Ankur              24           24                22
# 7         8    Laksh              26           25                23
# 8         9     Aman              23           18                25
# 9        10    Rajat              24           22                15

# %%
data.drop(index = 5, axis = 1, inplace = True)

# %%
data.describe()
# Out:
#         Roll No.  Data Structure  Mathematics  Operating System
# count   9.000000        9.000000     9.000000          9.000000
# mean    5.444444       24.111111    22.333333         19.000000
# std     3.205897        2.027588     2.828427          5.545268
# min     1.000000       21.000000    18.000000          9.000000
# 25%     3.000000       23.000000    21.000000         15.000000
# 50%     5.000000       24.000000    22.000000         21.000000
# 75%     8.000000       25.000000    24.000000         23.000000
# max    10.000000       28.000000    27.000000         25.000000

# %%
plt.plot(data["Name"], data["Data Structure"])
plt.title("Marks of students in Data Structure")
plt.xlabel("Students Name")
plt.ylabel("Students Marks")
plt.show()
